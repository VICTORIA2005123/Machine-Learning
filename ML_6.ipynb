# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
col_names = ["sepallength", "sepalwidth", "petallength", "petalwidth", "class"]
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
dataset = pd.read_csv(url,names=col_names)

# %%
dataset
# Out:
#      sepallength  sepalwidth  petallength  petalwidth           class
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
dataset_knn = dataset.values[:,0:4]
labels = dataset.values[:,-1]

# %%
dataset_knn
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3.0, 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5.0, 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5.0, 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3.0, 1.4, 0.1],
#        [4.3, 3.0, 1.1, 0.1],
#        [5.8, 4.0, 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1.0, 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5.0, 3.0, 1.6, 0.2],
#        [5.0, 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
#        [5.2, 4.1, 1.5, 0.1],
#        [5.5, 4.2, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.0, 3.2, 1.2, 0.2],
#        [5.5, 3.5, 1.3, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [4.4, 3.0, 1.3, 0.2],
#        [5.1, 3.4, 1.5, 0.2],
#        [5.0, 3.5, 1.3, 0.3],
#        [4.5, 2.3, 1.3, 0.3],
#        [4.4, 3.2, 1.3, 0.2],
#        [5.0, 3.5, 1.6, 0.6],
#        [5.1, 3.8, 1.9, 0.4],
#        [4.8, 3.0, 1.4, 0.3],
#        [5.1, 3.8, 1.6, 0.2],
#        [4.6, 3.2, 1.4, 0.2],
#        [5.3, 3.7, 1.5, 0.2],
#        [5.0, 3.3, 1.4, 0.2],
#        [7.0, 3.2, 4.7, 1.4],
#        [6.4, 3.2, 4.5, 1.5],
#        [6.9, 3.1, 4.9, 1.5],
#        [5.5, 2.3, 4.0, 1.3],
#        [6.5, 2.8, 4.6, 1.5],
#        [5.7, 2.8, 4.5, 1.3],
#        [6.3, 3.3, 4.7, 1.6],
#        [4.9, 2.4, 3.3, 1.0],
#        [6.6, 2.9, 4.6, 1.3],
#        [5.2, 2.7, 3.9, 1.4],
#        [5.0, 2.0, 3.5, 1.0],
#        [5.9, 3.0, 4.2, 1.5],
#        [6.0, 2.2, 4.0, 1.0],
#        [6.1, 2.9, 4.7, 1.4],
#        [5.6, 2.9, 3.6, 1.3],
#        [6.7, 3.1, 4.4, 1.4],
#        [5.6, 3.0, 4.5, 1.5],
#        [5.8, 2.7, 4.1, 1.0],
#        [6.2, 2.2, 4.5, 1.5],
#        [5.6, 2.5, 3.9, 1.1],
#        [5.9, 3.2, 4.8, 1.8],
#        [6.1, 2.8, 4.0, 1.3],
#        [6.3, 2.5, 4.9, 1.5],
#        [6.1, 2.8, 4.7, 1.2],
#        [6.4, 2.9, 4.3, 1.3],
#        [6.6, 3.0, 4.4, 1.4],
#        [6.8, 2.8, 4.8, 1.4],
#        [6.7, 3.0, 5.0, 1.7],
#        [6.0, 2.9, 4.5, 1.5],
#        [5.7, 2.6, 3.5, 1.0],
#        [5.5, 2.4, 3.8, 1.1],
#        [5.5, 2.4, 3.7, 1.0],
#        [5.8, 2.7, 3.9, 1.2],
#        [6.0, 2.7, 5.1, 1.6],
#        [5.4, 3.0, 4.5, 1.5],
#        [6.0, 3.4, 4.5, 1.6],
#        [6.7, 3.1, 4.7, 1.5],
#        [6.3, 2.3, 4.4, 1.3],
#        [5.6, 3.0, 4.1, 1.3],
#        [5.5, 2.5, 4.0, 1.3],
#        [5.5, 2.6, 4.4, 1.2],
#        [6.1, 3.0, 4.6, 1.4],
#        [5.8, 2.6, 4.0, 1.2],
#        [5.0, 2.3, 3.3, 1.0],
#        [5.6, 2.7, 4.2, 1.3],
#        [5.7, 3.0, 4.2, 1.2],
#        [5.7, 2.9, 4.2, 1.3],
#        [6.2, 2.9, 4.3, 1.3],
#        [5.1, 2.5, 3.0, 1.1],
#        [5.7, 2.8, 4.1, 1.3],
#        [6.3, 3.3, 6.0, 2.5],
#        [5.8, 2.7, 5.1, 1.9],
#        [7.1, 3.0, 5.9, 2.1],
#        [6.3, 2.9, 5.6, 1.8],
#        [6.5, 3.0, 5.8, 2.2],
#        [7.6, 3.0, 6.6, 2.1],
#        [4.9, 2.5, 4.5, 1.7],
#        [7.3, 2.9, 6.3, 1.8],
#        [6.7, 2.5, 5.8, 1.8],
#        [7.2, 3.6, 6.1, 2.5],
#        [6.5, 3.2, 5.1, 2.0],
#        [6.4, 2.7, 5.3, 1.9],
#        [6.8, 3.0, 5.5, 2.1],
#        [5.7, 2.5, 5.0, 2.0],
#        [5.8, 2.8, 5.1, 2.4],
#        [6.4, 3.2, 5.3, 2.3],
#        [6.5, 3.0, 5.5, 1.8],
#        [7.7, 3.8, 6.7, 2.2],
#        [7.7, 2.6, 6.9, 2.3],
#        [6.0, 2.2, 5.0, 1.5],
#        [6.9, 3.2, 5.7, 2.3],
#        [5.6, 2.8, 4.9, 2.0],
#        [7.7, 2.8, 6.7, 2.0],
#        [6.3, 2.7, 4.9, 1.8],
#        [6.7, 3.3, 5.7, 2.1],
#        [7.2, 3.2, 6.0, 1.8],
#        [6.2, 2.8, 4.8, 1.8],
#        [6.1, 3.0, 4.9, 1.8],
#        [6.4, 2.8, 5.6, 2.1],
#        [7.2, 3.0, 5.8, 1.6],
#        [7.4, 2.8, 6.1, 1.9],
#        [7.9, 3.8, 6.4, 2.0],
#        [6.4, 2.8, 5.6, 2.2],
#        [6.3, 2.8, 5.1, 1.5],
#        [6.1, 2.6, 5.6, 1.4],
#        [7.7, 3.0, 6.1, 2.3],
#        [6.3, 3.4, 5.6, 2.4],
#        [6.4, 3.1, 5.5, 1.8],
#        [6.0, 3.0, 4.8, 1.8],
#        [6.9, 3.1, 5.4, 2.1],
#        [6.7, 3.1, 5.6, 2.4],
#        [6.9, 3.1, 5.1, 2.3],
#        [5.8, 2.7, 5.1, 1.9],
#        [6.8, 3.2, 5.9, 2.3],
#        [6.7, 3.3, 5.7, 2.5],
#        [6.7, 3.0, 5.2, 2.3],
#        [6.3, 2.5, 5.0, 1.9],
#        [6.5, 3.0, 5.2, 2.0],
#        [6.2, 3.4, 5.4, 2.3],
#        [5.9, 3.0, 5.1, 1.8]], dtype=object)

# %%
# Define the function to find the distance
import math
def distance(x1,x2):
  distances = 0.0
  for i in range(len(x1)):
    distances += (x1[i]-x2[i])**2
  return (math.sqrt(distances))

# %%
testing_data = dataset.values[5,0:4]

# %%
distance_cumm = []
for i in range(len(dataset_knn)):
  distance_cumm.append([distance(dataset_knn[i],testing_data),labels[i]])

# %%
distance_cumm
# Out:
# [[0.6164414002968979, 'Iris-setosa'],
#  [1.0908712114635715, 'Iris-setosa'],
#  [1.0862780491200215, 'Iris-setosa'],
#  [1.1661903789690604, 'Iris-setosa'],
#  [0.6164414002968979, 'Iris-setosa'],
#  [0.0, 'Iris-setosa'],
#  [0.9949874371066205, 'Iris-setosa'],
#  [0.7000000000000002, 'Iris-setosa'],
#  [1.4594519519326423, 'Iris-setosa'],
#  [1.0099504938362076, 'Iris-setosa'],
#  [0.3464101615137753, 'Iris-setosa'],
#  [0.8124038404635965, 'Iris-setosa'],
#  [1.1618950038622253, 'Iris-setosa'],
#  [1.5716233645501714, 'Iris-setosa'],
#  [0.6782329983125266, 'Iris-setosa'],
#  [0.6164414002968979, 'Iris-setosa'],
#  [0.3999999999999999, 'Iris-setosa'],
#  [0.5916079783099619, 'Iris-setosa'],
#  [0.33166247903553986, 'Iris-setosa'],
#  [0.38729833462074226, 'Iris-setosa'],
#  [0.5385164807134505, 'Iris-setosa'],
#  [0.41231056256176646, 'Iris-setosa'],
#  [1.1224972160321829, 'Iris-setosa'],
#  [0.6782329983125271, 'Iris-setosa'],
#  [0.8306623862918079, 'Iris-setosa'],
#  [1.0099504938362078, 'Iris-setosa'],
#  [0.6480740698407862, 'Iris-setosa'],
#  [0.529150262212918, 'Iris-setosa'],
#  [0.6480740698407862, 'Iris-setosa'],
#  [1.014889156509222, 'Iris-setosa'],
#  [1.0246950765959602, 'Iris-setosa'],
#  [0.5385164807134504, 'Iris-setosa'],
#  [0.45825756949558394, 'Iris-setosa'],
#  [0.4795831523312721, 'Iris-setosa'],
#  [1.0099504938362076, 'Iris-setosa'],
#  [0.9695359714832658, 'Iris-setosa'],
#  [0.6082762530298218, 'Iris-setosa'],
#  [1.0099504938362076, 'Iris-setosa'],
#  [1.4177446878757824, 'Iris-setosa'],
#  [0.6480740698407863, 'Iris-setosa'],
#  [0.7000000000000001, 'Iris-setosa'],
#  [1.881488772222678, 'Iris-setosa'],
#  [1.2999999999999998, 'Iris-setosa'],
#  [0.608276253029822, 'Iris-setosa'],
#  [0.3741657386773947, 'Iris-setosa'],
#  [1.1269427669584646, 'Iris-setosa'],
#  [0.38729833462074226, 'Iris-setosa'],
#  [1.1224972160321829, 'Iris-setosa'],
#  [0.36055512754639896, 'Iris-setosa'],
#  [0.8062257748298551, 'Iris-setosa'],
#  [3.6124783736376886, 'Iris-versicolor'],
#  [3.246536616149585, 'Iris-versicolor'],
#  [3.786819245752298, 'Iris-versicolor'],
#  [2.9444863728670914, 'Iris-versicolor'],
#  [3.4698703145794942, 'Iris-versicolor'],
#  [3.1543620591175006, 'Iris-versicolor'],
#  [3.407345007480164, 'Iris-versicolor'],
#  [2.328089345364563, 'Iris-versicolor'],
#  [3.4146742157927736, 'Iris-versicolor'],
#  [2.705549851693737, 'Iris-versicolor'],
#  [2.7147743920996454, 'Iris-versicolor'],
#  [2.9189039038652846, 'Iris-versicolor'],
#  [2.983286778035259, 'Iris-versicolor'],
#  [3.3896902513356584, 'Iris-versicolor'],
#  [2.3366642891095846, 'Iris-versicolor'],
#  [3.258834147360065, 'Iris-versicolor'],
#  [3.1464265445104544, 'Iris-versicolor'],
#  [2.77848879788996, 'Iris-versicolor'],
#  [3.5468295701936396, 'Iris-versicolor'],
#  [2.7073972741361767, 'Iris-versicolor'],
#  [3.5085609585697664, 'Iris-versicolor'],
#  [2.792848008753788, 'Iris-versicolor'],
#  [3.770941526992961, 'Iris-versicolor'],
#  [3.3674916480965473, 'Iris-versicolor'],
#  [3.0935416596516037, 'Iris-versicolor'],
#  [3.246536616149585, 'Iris-versicolor'],
#  [3.7121422386541165, 'Iris-versicolor'],
#  [3.883297567789519, 'Iris-versicolor'],
#  [3.2264531609803355, 'Iris-versicolor'],
#  [2.3194827009486403, 'Iris-versicolor'],
#  [2.6758176320519302, 'Iris-versicolor'],
#  [2.5729360660537215, 'Iris-versicolor'],
#  [2.660826939130014, 'Iris-versicolor'],
#  [3.8470768123342687, 'Iris-versicolor'],
#  [3.1400636936215163, 'Iris-versicolor'],
#  [3.144837038703278, 'Iris-versicolor'],
#  [3.5411862419251547, 'Iris-versicolor'],
#  [3.38673884437522, 'Iris-versicolor'],
#  [2.7239676943752467, 'Iris-versicolor'],
#  [2.840774542268358, 'Iris-versicolor'],
#  [3.10322412983658, 'Iris-versicolor'],
#  [3.2726136343907135, 'Iris-versicolor'],
#  [2.78926513619627, 'Iris-versicolor'],
#  [2.3748684174075834, 'Iris-versicolor'],
#  [2.9223278392404914, 'Iris-versicolor'],
#  [2.7910571473905725, 'Iris-versicolor'],
#  [2.8548204847240397, 'Iris-versicolor'],
#  [3.0347981810987035, 'Iris-versicolor'],
#  [2.0566963801203135, 'Iris-versicolor'],
#  [2.8053520278211073, 'Iris-versicolor'],
#  [4.906118628814432, 'Iris-virginica'],
#  [3.9255572852781038, 'Iris-virginica'],
#  [4.922397789695586, 'Iris-virginica'],
#  [4.356604182158392, 'Iris-virginica'],
#  [4.697871858618538, 'Iris-virginica'],
#  [5.705260730238364, 'Iris-virginica'],
#  [3.4263683398023628, 'Iris-virginica'],
#  [5.265928218272634, 'Iris-virginica'],
#  [4.734976240700686, 'Iris-virginica'],
#  [5.205766033928147, 'Iris-virginica'],
#  [3.977436360270268, 'Iris-virginica'],
#  [4.201190307520001, 'Iris-virginica'],
#  [4.483302354291979, 'Iris-virginica'],
#  [3.937003937005905, 'Iris-virginica'],
#  [4.114608122288196, 'Iris-virginica'],
#  [4.249705872175156, 'Iris-virginica'],
#  [4.291852746774986, 'Iris-virginica'],
#  [5.791372894228103, 'Iris-virginica'],
#  [6.134329629226, 'Iris-virginica'],
#  [3.9179076048319463, 'Iris-virginica'],
#  [4.727578661429125, 'Iris-virginica'],
#  [3.748332962798263, 'Iris-virginica'],
#  [5.8360945845659495, 'Iris-virginica'],
#  [3.8013155617496426, 'Iris-virginica'],
#  [4.57602447545902, 'Iris-virginica'],
#  [4.917316341257699, 'Iris-virginica'],
#  [3.66333181680284, 'Iris-virginica'],
#  [3.6742346141747673, 'Iris-virginica'],
#  [4.506661735697499, 'Iris-virginica'],
#  [4.722287581247038, 'Iris-virginica'],
#  [5.1788029504896205, 'Iris-virginica'],
#  [5.5596762495670555, 'Iris-virginica'],
#  [4.545327270945404, 'Iris-virginica'],
#  [3.8457769046058816, 'Iris-virginica'],
#  [4.288356328478312, 'Iris-virginica'],
#  [5.3916602266834275, 'Iris-virginica'],
#  [4.502221673796171, 'Iris-virginica'],
#  [4.24735211631906, 'Iris-virginica'],
#  [3.569313659514949, 'Iris-virginica'],
#  [4.412482294582042, 'Iris-virginica'],
#  [4.641120554348917, 'Iris-virginica'],
#  [4.249705872175155, 'Iris-virginica'],
#  [3.9255572852781038, 'Iris-virginica'],
#  [4.868264577855234, 'Iris-virginica'],
#  [4.739198244429114, 'Iris-virginica'],
#  [4.28485705712571, 'Iris-virginica'],
#  [3.9887341350358256, 'Iris-virginica'],
#  [4.102438299353203, 'Iris-virginica'],
#  [4.264973622427225, 'Iris-virginica'],
#  [3.818376618407356, 'Iris-virginica']]

# %%
distance_cumm.sort()

# %%
distance_cumm
# Out:
# [[0.0, 'Iris-setosa'],
#  [0.33166247903553986, 'Iris-setosa'],
#  [0.3464101615137753, 'Iris-setosa'],
#  [0.36055512754639896, 'Iris-setosa'],
#  [0.3741657386773947, 'Iris-setosa'],
#  [0.38729833462074226, 'Iris-setosa'],
#  [0.38729833462074226, 'Iris-setosa'],
#  [0.3999999999999999, 'Iris-setosa'],
#  [0.41231056256176646, 'Iris-setosa'],
#  [0.45825756949558394, 'Iris-setosa'],
#  [0.4795831523312721, 'Iris-setosa'],
#  [0.529150262212918, 'Iris-setosa'],
#  [0.5385164807134504, 'Iris-setosa'],
#  [0.5385164807134505, 'Iris-setosa'],
#  [0.5916079783099619, 'Iris-setosa'],
#  [0.6082762530298218, 'Iris-setosa'],
#  [0.608276253029822, 'Iris-setosa'],
#  [0.6164414002968979, 'Iris-setosa'],
#  [0.6164414002968979, 'Iris-setosa'],
#  [0.6164414002968979, 'Iris-setosa'],
#  [0.6480740698407862, 'Iris-setosa'],
#  [0.6480740698407862, 'Iris-setosa'],
#  [0.6480740698407863, 'Iris-setosa'],
#  [0.6782329983125266, 'Iris-setosa'],
#  [0.6782329983125271, 'Iris-setosa'],
#  [0.7000000000000001, 'Iris-setosa'],
#  [0.7000000000000002, 'Iris-setosa'],
#  [0.8062257748298551, 'Iris-setosa'],
#  [0.8124038404635965, 'Iris-setosa'],
#  [0.8306623862918079, 'Iris-setosa'],
#  [0.9695359714832658, 'Iris-setosa'],
#  [0.9949874371066205, 'Iris-setosa'],
#  [1.0099504938362076, 'Iris-setosa'],
#  [1.0099504938362076, 'Iris-setosa'],
#  [1.0099504938362076, 'Iris-setosa'],
#  [1.0099504938362078, 'Iris-setosa'],
#  [1.014889156509222, 'Iris-setosa'],
#  [1.0246950765959602, 'Iris-setosa'],
#  [1.0862780491200215, 'Iris-setosa'],
#  [1.0908712114635715, 'Iris-setosa'],
#  [1.1224972160321829, 'Iris-setosa'],
#  [1.1224972160321829, 'Iris-setosa'],
#  [1.1269427669584646, 'Iris-setosa'],
#  [1.1618950038622253, 'Iris-setosa'],
#  [1.1661903789690604, 'Iris-setosa'],
#  [1.2999999999999998, 'Iris-setosa'],
#  [1.4177446878757824, 'Iris-setosa'],
#  [1.4594519519326423, 'Iris-setosa'],
#  [1.5716233645501714, 'Iris-setosa'],
#  [1.881488772222678, 'Iris-setosa'],
#  [2.0566963801203135, 'Iris-versicolor'],
#  [2.3194827009486403, 'Iris-versicolor'],
#  [2.328089345364563, 'Iris-versicolor'],
#  [2.3366642891095846, 'Iris-versicolor'],
#  [2.3748684174075834, 'Iris-versicolor'],
#  [2.5729360660537215, 'Iris-versicolor'],
#  [2.660826939130014, 'Iris-versicolor'],
#  [2.6758176320519302, 'Iris-versicolor'],
#  [2.705549851693737, 'Iris-versicolor'],
#  [2.7073972741361767, 'Iris-versicolor'],
#  [2.7147743920996454, 'Iris-versicolor'],
#  [2.7239676943752467, 'Iris-versicolor'],
#  [2.77848879788996, 'Iris-versicolor'],
#  [2.78926513619627, 'Iris-versicolor'],
#  [2.7910571473905725, 'Iris-versicolor'],
#  [2.792848008753788, 'Iris-versicolor'],
#  [2.8053520278211073, 'Iris-versicolor'],
#  [2.840774542268358, 'Iris-versicolor'],
#  [2.8548204847240397, 'Iris-versicolor'],
#  [2.9189039038652846, 'Iris-versicolor'],
#  [2.9223278392404914, 'Iris-versicolor'],
#  [2.9444863728670914, 'Iris-versicolor'],
#  [2.983286778035259, 'Iris-versicolor'],
#  [3.0347981810987035, 'Iris-versicolor'],
#  [3.0935416596516037, 'Iris-versicolor'],
#  [3.10322412983658, 'Iris-versicolor'],
#  [3.1400636936215163, 'Iris-versicolor'],
#  [3.144837038703278, 'Iris-versicolor'],
#  [3.1464265445104544, 'Iris-versicolor'],
#  [3.1543620591175006, 'Iris-versicolor'],
#  [3.2264531609803355, 'Iris-versicolor'],
#  [3.246536616149585, 'Iris-versicolor'],
#  [3.246536616149585, 'Iris-versicolor'],
#  [3.258834147360065, 'Iris-versicolor'],
#  [3.2726136343907135, 'Iris-versicolor'],
#  [3.3674916480965473, 'Iris-versicolor'],
#  [3.38673884437522, 'Iris-versicolor'],
#  [3.3896902513356584, 'Iris-versicolor'],
#  [3.407345007480164, 'Iris-versicolor'],
#  [3.4146742157927736, 'Iris-versicolor'],
#  [3.4263683398023628, 'Iris-virginica'],
#  [3.4698703145794942, 'Iris-versicolor'],
#  [3.5085609585697664, 'Iris-versicolor'],
#  [3.5411862419251547, 'Iris-versicolor'],
#  [3.5468295701936396, 'Iris-versicolor'],
#  [3.569313659514949, 'Iris-virginica'],
#  [3.6124783736376886, 'Iris-versicolor'],
#  [3.66333181680284, 'Iris-virginica'],
#  [3.6742346141747673, 'Iris-virginica'],
#  [3.7121422386541165, 'Iris-versicolor'],
#  [3.748332962798263, 'Iris-virginica'],
#  [3.770941526992961, 'Iris-versicolor'],
#  [3.786819245752298, 'Iris-versicolor'],
#  [3.8013155617496426, 'Iris-virginica'],
#  [3.818376618407356, 'Iris-virginica'],
#  [3.8457769046058816, 'Iris-virginica'],
#  [3.8470768123342687, 'Iris-versicolor'],
#  [3.883297567789519, 'Iris-versicolor'],
#  [3.9179076048319463, 'Iris-virginica'],
#  [3.9255572852781038, 'Iris-virginica'],
#  [3.9255572852781038, 'Iris-virginica'],
#  [3.937003937005905, 'Iris-virginica'],
#  [3.977436360270268, 'Iris-virginica'],
#  [3.9887341350358256, 'Iris-virginica'],
#  [4.102438299353203, 'Iris-virginica'],
#  [4.114608122288196, 'Iris-virginica'],
#  [4.201190307520001, 'Iris-virginica'],
#  [4.24735211631906, 'Iris-virginica'],
#  [4.249705872175155, 'Iris-virginica'],
#  [4.249705872175156, 'Iris-virginica'],
#  [4.264973622427225, 'Iris-virginica'],
#  [4.28485705712571, 'Iris-virginica'],
#  [4.288356328478312, 'Iris-virginica'],
#  [4.291852746774986, 'Iris-virginica'],
#  [4.356604182158392, 'Iris-virginica'],
#  [4.412482294582042, 'Iris-virginica'],
#  [4.483302354291979, 'Iris-virginica'],
#  [4.502221673796171, 'Iris-virginica'],
#  [4.506661735697499, 'Iris-virginica'],
#  [4.545327270945404, 'Iris-virginica'],
#  [4.57602447545902, 'Iris-virginica'],
#  [4.641120554348917, 'Iris-virginica'],
#  [4.697871858618538, 'Iris-virginica'],
#  [4.722287581247038, 'Iris-virginica'],
#  [4.727578661429125, 'Iris-virginica'],
#  [4.734976240700686, 'Iris-virginica'],
#  [4.739198244429114, 'Iris-virginica'],
#  [4.868264577855234, 'Iris-virginica'],
#  [4.906118628814432, 'Iris-virginica'],
#  [4.917316341257699, 'Iris-virginica'],
#  [4.922397789695586, 'Iris-virginica'],
#  [5.1788029504896205, 'Iris-virginica'],
#  [5.205766033928147, 'Iris-virginica'],
#  [5.265928218272634, 'Iris-virginica'],
#  [5.3916602266834275, 'Iris-virginica'],
#  [5.5596762495670555, 'Iris-virginica'],
#  [5.705260730238364, 'Iris-virginica'],
#  [5.791372894228103, 'Iris-virginica'],
#  [5.8360945845659495, 'Iris-virginica'],
#  [6.134329629226, 'Iris-virginica']]

# %%
k=8
labels_topk = []
for i in range(1,k+1):
  labels_topk.append(distance_cumm[i][1])

# %%
labels_topk
# Out:
# ['Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa']

# %%
from collections import Counter
count = Counter(labels_topk)

# %%
count
# Out:
# Counter({'Iris-setosa': 8})

# %%
print("Final predicted label:", count.most_common(1)[0][0])
# Out:
# Final predicted label: Iris-setosa
